# %% [markdown]
# # ชื่อ ปรียานุช
# # นามสกุล สุภาสืบ
# # รหัสนักศึกษา 61070306

# %% [markdown]
# # Lab AI for Medicine : Heart Dataset
# ชุดข้อมูลโรคหัวใจ ประกอบด้วยฐานข้อมูล 4 ฐานข้อมูลเกี่ยวกับการวินิจฉัยโรคหัวใจ แอตทริบิวต์ทั้งหมดมีค่าเป็นตัวเลข ข้อมูลถูกรวบรวมจากไฟล์  4 สถานที่ดังต่อไปนี้:
#
#       1 มูลนิธิคลีฟแลนด์คลินิก (cleveland.data)
#       2 สถาบันโรคหัวใจแห่งฮังการีบูดาเปสต์ (Hungarian.data)
#       3 V.A. ศูนย์การแพทย์ลองบีชแคลิฟอร์เนีย (long-beach-va.data)
#       4 โรงพยาบาลมหาวิทยาลัยซูริกประเทศสวิตเซอร์แลนด์ (ข้อมูลสวิตเซอร์แลนด์)
#
# แต่ละฐานข้อมูลมีรูปแบบเดียวกัน ในขณะที่ฐานข้อมูลมี 76 แอตทริบิวต์ มีเพียง 14 รายการเท่านั้นที่ใช้จริง
#
# ข้อมูลโรคหัวใจชุดนี้มี 76 แอตทริบิวต์ ซึ่งมีรายละเอียดดังนี้
#
# 1 id: patient identification number
#
# 2 ccf: social security number (I replaced this with a dummy value of 0)
#
# 3 age: age in years
#
# 4 sex: sex (1 = male; 0 = female)
#
# 5 painloc: chest pain location (1 = substernal; 0 = otherwise)
#
# 6 painexer (1 = provoked by exertion; 0 = otherwise)
#
# 7 relrest (1 = relieved after rest; 0 = otherwise)
#
# 8 pncaden (sum of 5, 6, and 7)
#
# 9 cp: chest pain type
# -- Value 1: typical angina
# -- Value 2: atypical angina
# -- Value 3: non-anginal pain
# -- Value 4: asymptomatic
#
# 10 trestbps: resting blood pressure (in mm Hg on admission to the hospital)
#
# 11 htn
#
# 12 chol: serum cholestoral in mg/dl
#
# 13 smoke: I believe this is 1 = yes; 0 = no (is or is not a smoker)
#
# 14 cigs (cigarettes per day)
#
# 15 years (number of years as a smoker)
#
# 16 fbs: (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
#
# 17 dm (1 = history of diabetes; 0 = no such history)
#
# 18 famhist: family history of coronary artery disease (1 = yes; 0 = no)
#
# 19 restecg: resting electrocardiographic results
# -- Value 0: normal
# -- Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
# -- Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria
#
# 20 ekgmo (month of exercise ECG reading)
#
# 21 ekgday(day of exercise ECG reading)
#
# 22 ekgyr (year of exercise ECG reading)
#
# 23 dig (digitalis used furing exercise ECG: 1 = yes; 0 = no)
#
# 24 prop (Beta blocker used during exercise ECG: 1 = yes; 0 = no)
#
# 25 nitr (nitrates used during exercise ECG: 1 = yes; 0 = no)
#
# 26 pro (calcium channel blocker used during exercise ECG: 1 = yes; 0 = no)
#
# 27 diuretic (diuretic used used during exercise ECG: 1 = yes; 0 = no)
#
# 28 proto: exercise protocol
#   1 = Bruce
#   2 = Kottus
#   3 = McHenry
#   4 = fast Balke
#   5 = Balke
#   6 = Noughton
#   7 = bike 150 kpa min/min (Not sure if "kpa min/min" is what was written!)
#   8 = bike 125 kpa min/min
#   9 = bike 100 kpa min/min
#   10 = bike 75 kpa min/min
#   11 = bike 50 kpa min/min
#   12 = arm ergometer
#
# 29 thaldur: duration of exercise test in minutes
#
# 30 thaltime: time when ST measure depression was noted
#
# 31 met: mets achieved
#
# 32 thalach: maximum heart rate achieved
#
# 33 thalrest: resting heart rate
#
# 34 tpeakbps: peak exercise blood pressure (first of 2 parts)
#
# 35 tpeakbpd: peak exercise blood pressure (second of 2
# parts)
#
# 36 dummy
#
# 37 trestbpd: resting blood pressure
#
# 38 exang: exercise induced angina (1 = yes; 0 = no)
#
# 39 xhypo: (1 = yes; 0 = no)
#
# 40 oldpeak = ST depression induced by exercise relative to rest
#
# 41 slope: the slope of the peak exercise ST segment
# -- Value 1: upsloping
# -- Value 2: flat
# -- Value 3: downsloping
#
# 42 rldv5: height at rest
#
# 43 rldv5e: height at peak exercise
#
# 44 ca: number of major vessels (0-3) colored by flourosopy
#
# 45 restckm: irrelevant
#
# 46 exerckm: irrelevant
#
# 47 restef: rest raidonuclid (sp?) ejection fraction
#
# 48 restwm: rest wall (sp?) motion abnormality
#   0 = none
#   1 = mild or moderate
#   2 = moderate or severe
#   3 = akinesis or dyskmem (sp?)
#
# 49 exeref: exercise radinalid (sp?) ejection fraction
#
# 50 exerwm: exercise wall (sp?) motion
#
# 51 thal: 3 = normal; 6 = fixed defect; 7 = reversable defect
#
# 52 thalsev: not used
#
# 53 thalpul: not used
#
# 54 earlobe: not used
#
# 55 cmo: month of cardiac cath (sp?) (perhaps "call")
#
# 56 cday: day of cardiac cath (sp?)
#
# 57 cyr: year of cardiac cath (sp?)
#
# 58 num: diagnosis of heart disease (angiographic disease status)
# -- Value 0: < 50% diameter narrowing
# -- Value 1: > 50% diameter narrowing
# (in any major vessel: attributes 59 through 68 are vessels)
#
# 59 lmt
#
# 60 ladprox
#
# 61 laddist
#
# 62 diag
#
# 63 cxmain
#
# 64 ramus
#
# 65 om1
#
# 66 om2
#
# 67 rcaprox
#
# 68 rcadist
#
# 69 lvx1: not used
#
# 70 lvx2: not used
#
# 71 lvx3: not used
#
# 72 lvx4: not used
#
# 73 lvf: not used
#
# 74 cathef: not used
#
# 75 junk: not used
#
# 76 name: last name of patient (I replaced this with the dummy string "name")

# %% [markdown]
# จำนวนข้อมูลโรคหัวใจมีดังนี้ :
#
# *   Cleveland     :     303 Records
# *   Hungarian     :     294 Records
# *   Switzerland   :     123 Records
# *   Long Beach VA :     200 Records

# %% [markdown]
# Attribute Information:
#    -- Only 14 used
#
#       -- 1. #3  (age)
#       -- 2. #4  (sex)
#       -- 3. #9  (cp)
#       -- 4. #10 (trestbps)
#       -- 5. #12 (chol)
#       -- 6. #16 (fbs)
#       -- 7. #19 (restecg)
#       -- 8. #32 (thalach)
#       -- 9. #38 (exang)
#       -- 10. #40 (oldpeak)
#       -- 11. #41 (slope)
#       -- 12. #44 (ca)
#       -- 13. #51 (thal)
#       -- 14. #58 (num)       (the predicted attribute)

# %%
#! pip install tensorflow
#! pip install keras

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn.model_selection as mod
import sklearn.neighbors as nei
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import LeaveOneOut
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score, classification_report, precision_recall_curve, average_precision_score 
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import RFECV
from sklearn.svm import SVC
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import *
import operator

# %%
# %matplotlib inline
import matplotlib
from matplotlib import pyplot
from sklearn import preprocessing
# %matplotlib inline
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import LabelEncoder
from scipy.stats import chi2_contingency
from scipy.stats import chi2
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2 as sklearn_chi2

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
import tensorflow as tf

# %% [markdown]
# # วัตถุประสงค์

# %% [markdown]
# โครงการนี้มีวัตถุประสงค์เพื่อช่วยให้ผู้เชี่ยวชาญด้านสุขภาพทำการวินิจฉัยได้ง่ายขึ้นโดยใช้เทคนิค Machine Learning เพื่อเป็นการเชื่อมกันระหว่างความรู้กับชุดข้อมูลที่ทำการบันทึกไว้สามารถนำไปใช้ประโยขน์ได้ ดังนั้นในการทดลองนี้เราจะนำเทคนิค Machine learning มาประยุกต์ใช้กับ Heart Dataset

# %% [markdown]
# Import and Loading Dataset

# %%
df = pd.read_csv('Processed_cleveland_data.csv')
df
# Out:
#      Age  Sex  Chest pain type  Trestbps  Chol  Fbs  Restecg  Thalach  Exang  Oldpeak  Slope Ca Thal  Num_diagnosis
# 0     63    1                1       145   233    1        2      150      0      2.3      3  0    6              0
# 1     67    1                4       160   286    0        2      108      1      1.5      2  3    3              2
# 2     67    1                4       120   229    0        2      129      1      2.6      2  2    7              1
# 3     37    1                3       130   250    0        0      187      0      3.5      3  0    3              0
# 4     41    0                2       130   204    0        2      172      0      1.4      1  0    3              0
# 5     56    1                2       120   236    0        0      178      0      0.8      1  0    3              0
# 6     62    0                4       140   268    0        2      160      0      3.6      3  2    3              3
# 7     57    0                4       120   354    0        0      163      1      0.6      1  0    3              0
# 8     63    1                4       130   254    0        2      147      0      1.4      2  1    7              2
# 9     53    1                4       140   203    1        2      155      1      3.1      3  0    7              1
# 10    57    1                4       140   192    0        0      148      0      0.4      2  0    6              0
# 11    56    0                2       140   294    0        2      153      0      1.3      2  0    3              0
# 12    56    1                3       130   256    1        2      142      1      0.6      2  1    6              2
# 13    44    1                2       120   263    0        0      173      0      0.0      1  0    7              0
# 14    52    1                3       172   199    1        0      162      0      0.5      1  0    7              0
# 15    57    1                3       150   168    0        0      174      0      1.6      1  0    3              0
# 16    48    1                2       110   229    0        0      168      0      1.0      3  0    7              1
# 17    54    1                4       140   239    0        0      160      0      1.2      1  0    3              0
# 18    48    0                3       130   275    0        0      139      0      0.2      1  0    3              0
# 19    49    1                2       130   266    0        0      171      0      0.6      1  0    3              0
# 20    64    1                1       110   211    0        2      144      1      1.8      2  0    3              0
# 21    58    0                1       150   283    1        2      162      0      1.0      1  0    3              0
# 22    58    1                2       120   284    0        2      160      0      1.8      2  0    3              1
# 297   57    0                4       140   241    0        0      123      1      0.2      2  0    7              1
# 298   45    1                1       110   264    0        0      132      0      1.2      2  0    7              1
# 299   68    1                4       144   193    1        0      141      0      3.4      2  2    7              2
# 300   57    1                4       130   131    0        0      115      1      1.2      2  1    7              3
# 301   57    0                2       130   236    0        2      174      0      0.0      2  1    3              1
# 302   38    1                3       138   175    0        0      173      0      0.0      1  ?    3              0

# %% [markdown]
# # Check Null Value

# %%
df.isnull().sum()
# Out:
# Age                0
# Sex                0
# Chest pain type    0
# Trestbps           0
# Chol               0
# Fbs                0
# Restecg            0
# Thalach            0
# Exang              0
# Oldpeak            0
# Slope              0
# Ca                 0
# Thal               0
# Num_diagnosis      0
# dtype: int64

# %% [markdown]
# # ตรวจสอบข้อมูลเพื่อจัดการ Missing Data

# %%
df.head(15)
# Out:
#     Age  Sex  Chest pain type  Trestbps  Chol  Fbs  Restecg  Thalach  Exang  Oldpeak  Slope Ca Thal  Num_diagnosis
# 0    63    1                1       145   233    1        2      150      0      2.3      3  0    6              0
# 1    67    1                4       160   286    0        2      108      1      1.5      2  3    3              2
# 2    67    1                4       120   229    0        2      129      1      2.6      2  2    7              1
# 3    37    1                3       130   250    0        0      187      0      3.5      3  0    3              0
# 4    41    0                2       130   204    0        2      172      0      1.4      1  0    3              0
# 5    56    1                2       120   236    0        0      178      0      0.8      1  0    3              0
# 6    62    0                4       140   268    0        2      160      0      3.6      3  2    3              3
# 7    57    0                4       120   354    0        0      163      1      0.6      1  0    3              0
# 8    63    1                4       130   254    0        2      147      0      1.4      2  1    7              2
# 9    53    1                4       140   203    1        2      155      1      3.1      3  0    7              1
# 10   57    1                4       140   192    0        0      148      0      0.4      2  0    6              0
# 11   56    0                2       140   294    0        2      153      0      1.3      2  0    3              0
# 12   56    1                3       130   256    1        2      142      1      0.6      2  1    6              2
# 13   44    1                2       120   263    0        0      173      0      0.0      1  0    7              0
# 14   52    1                3       172   199    1        0      162      0      0.5      1  0    7              0

# %%
df.Age.value_counts()
# Out:
# 58    19
# 57    17
# 54    16
# 59    14
# 52    13
# 51    12
# 60    12
# 62    11
# 44    11
# 56    11
# 64    10
# 41    10
# 63     9
# 67     9
# 55     8
# 45     8
# 42     8
# 53     8
# 61     8
# 65     8
# 43     8
# 66     7
# 50     7
# 48     7
# 46     7
# 49     5
# 47     5
# 39     4
# 35     4
# 68     4
# 70     4
# 40     3
# 71     3
# 69     3
# 34     2
# 37     2
# 38     2
# 77     1
# 76     1
# 74     1
# 29     1
# Name: Age, dtype: int64

# %%
df.Sex.value_counts()
# Out:
# 1    206
# 0     97
# Name: Sex, dtype: int64

# %%
df['Chest pain type'].value_counts()
# Out:
# 4    144
# 3     86
# 2     50
# 1     23
# Name: Chest pain type, dtype: int64

# %%
df.Trestbps.value_counts()
# Out:
# 120    37
# 130    36
# 140    32
# 110    19
# 150    17
# 138    12
# 128    12
# 125    11
# 160    11
# 112     9
# 132     8
# 118     7
# 124     6
# 135     6
# 108     6
# 145     5
# 134     5
# 152     5
# 122     4
# 170     4
# 100     4
# 3.2     2
# 2.5     2
# 1.1     2
# 3.5     1
# 1.3     1
# 5.6     1
# 0.7     1
# 2.9     1
# 3.1     1
# 3.8     1
# 2.1     1
# 6.2     1
# 4.4     1
# Name: Oldpeak, dtype: int64

# %%
df.Slope.value_counts()
# Out:
# 1    142
# 2    140
# 3     21
# Name: Slope, dtype: int64

# %%
df.Ca.value_counts()
# Out:
# 0    176
# 1     65
# 2     38
# 3     20
# ?      4
# Name: Ca, dtype: int64

# %%
df.Thal.value_counts()
# Out:
# 3    166
# 7    117
# 6     18
# ?      2
# Name: Thal, dtype: int64

# %%
df.Num_diagnosis.value_counts()
# Out:
# 0    164
# 1     55
# 2     36
# 3     35
# 4     13
# Name: Num_diagnosis, dtype: int64

# %% [markdown]
# จะเลือก
# - drop row Ca, Thal เนื่องจากค่า value ภายในคอลัมน์มีค่า '?'
# - drop row Num_diagnosis เนื่องจากมีค่า value ที่ไม่ถูกต้องคือ value 2 3 4

# %% [markdown]
# ต่อไปจะทำการ drop row ที่มีค่า '?' ด้วยคำสั่งต่อไปนี้

# %%
Ca = df[(df['Ca'] == '?')].index 
df.drop(Ca , inplace=True)

Thal = df[(df['Thal'] == '?')].index 
df.drop(Thal , inplace=True)

num2 = df[(df['Num_diagnosis'] == 2)].index 
df.drop(num2 , inplace=True)

num3 = df[(df['Num_diagnosis'] == 3)].index 
df.drop(num3 , inplace=True)

num4 = df[(df['Num_diagnosis'] == 4)].index 
df.drop(num4 , inplace=True)

# %%
df.Ca.value_counts()
# Out:
# 0    155
# 1     40
# 2     13
# 3      6
# Name: Ca, dtype: int64

# %%
df.Thal.value_counts()
# Out:
# 3    149
# 7     56
# 6      9
# Name: Thal, dtype: int64

# %%
df.Num_diagnosis.value_counts()
# Out:
# 0    160
# 1     54
# Name: Num_diagnosis, dtype: int64

# %%
df.head(15)
# Out:
#     Age  Sex  Chest pain type  Trestbps  Chol  Fbs  Restecg  Thalach  Exang  Oldpeak  Slope Ca Thal  Num_diagnosis
# 0    63    1                1       145   233    1        2      150      0      2.3      3  0    6              0
# 2    67    1                4       120   229    0        2      129      1      2.6      2  2    7              1
# 3    37    1                3       130   250    0        0      187      0      3.5      3  0    3              0
# 4    41    0                2       130   204    0        2      172      0      1.4      1  0    3              0
# 5    56    1                2       120   236    0        0      178      0      0.8      1  0    3              0
# 7    57    0                4       120   354    0        0      163      1      0.6      1  0    3              0
# 9    53    1                4       140   203    1        2      155      1      3.1      3  0    7              1
# 10   57    1                4       140   192    0        0      148      0      0.4      2  0    6              0
# 11   56    0                2       140   294    0        2      153      0      1.3      2  0    3              0
# 13   44    1                2       120   263    0        0      173      0      0.0      1  0    7              0
# 14   52    1                3       172   199    1        0      162      0      0.5      1  0    7              0
# 15   57    1                3       150   168    0        0      174      0      1.6      1  0    3              0
# 16   48    1                2       110   229    0        0      168      0      1.0      3  0    7              1
# 17   54    1                4       140   239    0        0      160      0      1.2      1  0    3              0
# 18   48    0                3       130   275    0        0      139      0      0.2      1  0    3              0

# %% [markdown]
# จาก output ด้านบนจะเห็นว่าข้อมูลไม่มีค่า value '?' อยู่แล้ว

# %% [markdown]
# # แสดง Attribute Distribution

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 214 entries, 0 to 301
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              214 non-null    int64
#  1   Sex              214 non-null    int64
#  2   Chest pain type  214 non-null    int64
#  3   Trestbps         214 non-null    int64
#  4   Chol             214 non-null    int64
#  5   Fbs              214 non-null    int64
#  6   Restecg          214 non-null    int64
#  7   Thalach          214 non-null    int64
#  8   Exang            214 non-null    int64
#  9   Oldpeak          214 non-null    float64
#  10  Slope            214 non-null    int64
#  11  Ca               214 non-null    object
#  12  Thal             214 non-null    object
#  13  Num_diagnosis    214 non-null    int64
# dtypes: float64(1), int64(11), object(2)
# memory usage: 25.1+ KB

# %% [markdown]
# ก่อนจะแสดง Attribute Distribution จะทำการแปลงค่า type ของข้อมูลอื่นที่ไม่ใช่ int ให้เป็น int ก่อนด้วยคำสั่งด้านล่างนี้

# %%
df = df.astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 214 entries, 0 to 301
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              214 non-null    int64
#  1   Sex              214 non-null    int64
#  2   Chest pain type  214 non-null    int64
#  3   Trestbps         214 non-null    int64
#  4   Chol             214 non-null    int64
#  5   Fbs              214 non-null    int64
#  6   Restecg          214 non-null    int64
#  7   Thalach          214 non-null    int64
#  8   Exang            214 non-null    int64
#  9   Oldpeak          214 non-null    int64
#  10  Slope            214 non-null    int64
#  11  Ca               214 non-null    int64
#  12  Thal             214 non-null    int64
#  13  Num_diagnosis    214 non-null    int64
# dtypes: int64(14)
# memory usage: 25.1 KB

# %%
df.hist(bins=50, figsize=(15, 12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D5638BFCD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D563FA81C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D563FD8640>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D564003A90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D564031EE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D56406A2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D56406A3A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D564095790>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D5640F55E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D56411CD60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D564153550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D56417CCD0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D5641B1490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D5641D9C10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D56420E310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D56422CC70>]],
#       dtype=object)

# %% [markdown]
# จาก output ด้านบนเป็นการแสดง histogram ของข้อมูล numeric ใน dataframe

# %%
df.plot(kind='density', subplots=True,figsize=(15, 28) ,sharex=False)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001D564EC5CD0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D564F42FD0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D5651BD460>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D5651DF8B0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D565203D00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D5652370D0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D5652371C0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D5652636A0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D5652BEEB0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D5652F0A30>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D5653281F0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D565350970>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D565385130>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D5653AE8B0>],
#       dtype=object)

# %% [markdown]
# จาก output ด้านบนเป็นการแสดง line graph density ของข้อมูล numeric ใน dataframe

# %%
df.plot(kind= 'box' , subplots=True, sharex=False, sharey=False, figsize=(35, 10))
# Out:
# Age                   AxesSubplot(0.125,0.125;0.0466867x0.755)
# Sex                AxesSubplot(0.181024,0.125;0.0466867x0.755)
# Chest pain type    AxesSubplot(0.237048,0.125;0.0466867x0.755)
# Trestbps           AxesSubplot(0.293072,0.125;0.0466867x0.755)
# Chol               AxesSubplot(0.349096,0.125;0.0466867x0.755)
# Fbs                 AxesSubplot(0.40512,0.125;0.0466867x0.755)
# Restecg            AxesSubplot(0.461145,0.125;0.0466867x0.755)
# Thalach            AxesSubplot(0.517169,0.125;0.0466867x0.755)
# Exang              AxesSubplot(0.573193,0.125;0.0466867x0.755)
# Oldpeak            AxesSubplot(0.629217,0.125;0.0466867x0.755)
# %%
feature_train, feature_test, target_train, target_test = mod.train_test_split(feature, target, test_size =0.20,random_state= 0)

# %%
feature_train2, feature_test2, target_train2, target_test2 = mod.train_test_split(feature, target, test_size =0.50,random_state= 0)

# %% [markdown]
# # Logistic Regression Method

# %% [markdown]
# ### เมื่อแบ่งข้อมูลแบบ simple hold out ที่ให้ train:80 test:20

# %%
model = LogisticRegression()
model.fit(feature_train, target_train)
predicted = model.predict(feature_test)
accuracy = accuracy_score(target_test, predicted)
print('accuracy = %.2f'%(accuracy))
# Out:
# accuracy = 0.79

# %%
cm = confusion_matrix(target_test, predicted)
print(cm)
# Out:
# [[30  0]
#  [ 9  4]]

# %%
print(classification_report(target_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        30
#            1       1.00      0.31      0.47        13
#
#     accuracy                           0.79        43
#    macro avg       0.88      0.65      0.67        43
# weighted avg       0.84      0.79      0.75        43

# %% [markdown]
# ### เมื่อแบ่งข้อมูลแบบ simple hold out ที่ให้ train:50 test:50

# %%
model = LogisticRegression()
model.fit(feature_train2, target_train2)
predicted2 = model.predict(feature_test2)
accuracy = accuracy_score(target_test2, predicted2)
print('accuracy = %.2f'%(accuracy))
# Out:
# accuracy = 0.80

# %%
cm = confusion_matrix(target_test2, predicted2)
print(cm)
# Out:
# [[78  5]
#  [16  8]]

# %%
print(classification_report(target_test2, predicted2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88        83
#            1       0.62      0.33      0.43        24
#
#     accuracy                           0.80       107
#    macro avg       0.72      0.64      0.66       107
# weighted avg       0.78      0.80      0.78       107

# %% [markdown]
# ### เมื่อแบ่งข้อมูลแบบ cross-validation

# %%
from sklearn import linear_model
model = linear_model.LogisticRegression(solver='liblinear')
acc_scores =  cross_val_score(model, feature, target, cv=10, scoring="accuracy")
print("Logistic Regression: Mean cross-validation accuracy = %.2f" % acc_scores.mean() )
# Out:
# Logistic Regression: Mean cross-validation accuracy = 0.79

# %% [markdown]
# ### สรุป
# - เมื่อแบ่งข้อมูลแบบ simple hold out ที่ให้ train:80 test:20 โมเดลมีค่า accuracy = 79%
# - เมื่อแบ่งข้อมูลแบบ simple hold out ที่ให้ train:50 test:50 โมเดลมีค่า accuracy = 80%
# - เมื่อแบ่งข้อมูลแบบ cross-validation โมเดลมีค่า accuracy = 79%
#
# ดังนั้นการแบ่งข้อมูลแบบ simple hold out ที่ให้ train:50 test:50 จะได้โมเดล Logistic Regression ที่มีค่า accuracy มากที่สุด = 80%

# %% [markdown]
# # k-NN with k = 4

# %% [markdown]
# ### เมื่อแบ่งข้อมูลแบบ simple hold out ที่ให้ train:80 test:20

# %%
model = KNeighborsClassifier(n_neighbors=4)
model.fit(feature_train, target_train)
predicted = model.predict(feature_test)
accuracy = accuracy_score(target_test, predicted)
print('accuracy = %.2f'%(accuracy))
# Out:
# accuracy = 0.72

# %% [markdown]
# #### Confusion Matrix

# %%
cm = confusion_matrix(target_test, predicted)
print(cm)
# Out:
# [[30  0]
#  [12  1]]

# %% [markdown]
# #### Precision

# %%
precision = metrics.precision_score(target_test, predicted)
print('precision = %.2f' %precision)
# Out:
# precision = 1.00

# %% [markdown]
# #### Recall

# %%
recall = metrics.recall_score(target_test, predicted)
print('recall = %.2f' %recall)
# Out:
# recall = 0.08

# %%
print(classification_report(target_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83        30
#            1       1.00      0.08      0.14        13
#
#     accuracy                           0.72        43
#    macro avg       0.86      0.54      0.49        43
# weighted avg       0.80      0.72      0.62        43

# %% [markdown]
# ### เมื่อแบ่งข้อมูลแบบ simple hold out ที่ให้ train:50 test:50

# %%
model = KNeighborsClassifier(n_neighbors=4)
model.fit(feature_train2, target_train2)
predicted2 = model.predict(feature_test2)
accuracy = accuracy_score(target_test2, predicted2)
print('accuracy = %.2f'%(accuracy))
# Out:
# accuracy = 0.76

# %% [markdown]
# #### Confusion Matrix

# %%
cm = confusion_matrix(target_test2, predicted2)
print(cm)
# Out:
# [[78  5]
#  [21  3]]

# %% [markdown]
# #### Precision

# %%
precision = metrics.precision_score(target_test2, predicted2)
print('precision = %.2f' %precision)
# Out:
# precision = 0.38

# %% [markdown]
# #### Recall

# %%
recall = metrics.recall_score(target_test2, predicted2)
print('recall = %.2f' %recall)
# Out:
# recall = 0.12

# %%
print(classification_report(target_test2, predicted2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.94      0.86        83
#            1       0.38      0.12      0.19        24
#
#     accuracy                           0.76       107
#    macro avg       0.58      0.53      0.52       107
# weighted avg       0.70      0.76      0.71       107

# %% [markdown]
# ### เมื่อแบ่งข้อมูลแบบ cross-validation

# %%
# create a single classifier
model = KNeighborsClassifier(n_neighbors=4)
# apply 2-fold cross-validation, measuring accuracy each time
#from sklearn.model_selection import cross_val_score
acc_scores = cross_val_score(model, feature, target, cv=10, scoring="accuracy")
print("KNN: Mean cross-validation accuracy = %.2f" % acc_scores.mean() )
# Out:
# KNN: Mean cross-validation accuracy = 0.74

# %% [markdown]
# ### สรุป
# - เมื่อแบ่งข้อมูลแบบ simple hold out ที่ให้ train:80 test:20 โมเดลมีค่า accuracy = 72%
# - เมื่อแบ่งข้อมูลแบบ simple hold out ที่ให้ train:50 test:50 โมเดลมีค่า accuracy = 76%
# - เมื่อแบ่งข้อมูลแบบ cross-validation โมเดลมีค่า accuracy = 74%
#
# ดังนั้นการแบ่งข้อมูลแบบ simple hold out ที่ให้ train:50 test:50 จะได้โมเดล KNN ที่มีค่า accuracy มากที่สุด = 76%

# %% [markdown]
# # SVM Method

# %% [markdown]
# ### เมื่อแบ่งข้อมูลแบบ simple hold out ที่ให้ train:80 test:20

# %%
model = svm.SVC(C=2, gamma='scale', kernel='linear')
model.fit(feature_train, target_train)
predicted = model.predict(feature_test)
accuracy = accuracy_score(target_test, predicted)
print('accuracy = %.2f'%(accuracy))
# Out:
# accuracy = 0.74

# %% [markdown]
# #### Confusion Matrix

# %%
cm = confusion_matrix(target_test, predicted)
print(cm)
# Out:
# [[28  2]
#  [ 9  4]]

# %% [markdown]
# #### Precision

# %%
precision = metrics.precision_score(target_test, predicted)
print('precision = %.2f' %precision)
# Out:
# precision = 0.67

# %% [markdown]
# #### Recall

# %%
recall = metrics.recall_score(target_test, predicted)
print('recall = %.2f' %recall)
# Out:
# recall = 0.31

# %%
print(classification_report(target_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.93      0.84        30
#            1       0.67      0.31      0.42        13
#
#     accuracy                           0.74        43
#    macro avg       0.71      0.62      0.63        43
# weighted avg       0.73      0.74      0.71        43

# %% [markdown]
# ### เมื่อแบ่งข้อมูลแบบ simple hold out ที่ให้ train:50 test:50

# %%
model = svm.SVC(C=2, gamma='scale', kernel='linear')
model.fit(feature_train2, target_train2)
predicted2 = model.predict(feature_test2)
accuracy = accuracy_score(target_test2, predicted2)
print('accuracy = %.2f'%(accuracy))
# Out:
# accuracy = 0.79

# %% [markdown]
# #### Confusion Matrix

# %%
cm = confusion_matrix(target_test2, predicted2)
print(cm)
# Out:
# [[78  5]
#  [17  7]]

# %% [markdown]
# #### Precision

# %%
recision = metrics.precision_score(target_test2, predicted2)
print('precision = %.2f' %precision)
# Out:
# precision = 0.67

# %% [markdown]
# #### Recall

# %%
recall = metrics.recall_score(target_test2, predicted2)
print('recall = %.2f' %recall)
# Out:
# recall = 0.29

# %%
print(classification_report(target_test2, predicted2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.94      0.88        83
#            1       0.58      0.29      0.39        24
#
#     accuracy                           0.79       107
#    macro avg       0.70      0.62      0.63       107
# weighted avg       0.77      0.79      0.77       107

# %% [markdown]
# ### เมื่อแบ่งข้อมูลแบบ cross-validation

# %%
model = SVC(gamma='scale')
acc_scores = cross_val_score(model, feature, target, cv=10, scoring="accuracy")
print("SVM: Mean cross-validation accuracy = %.2f" % acc_scores.mean() )
# Out:
# SVM: Mean cross-validation accuracy = 0.75

# %% [markdown]
# ### สรุป
# - เมื่อแบ่งข้อมูลแบบ simple hold out ที่ให้ train:80 test:20 โมเดลมีค่า accuracy = 74%
# - เมื่อแบ่งข้อมูลแบบ simple hold out ที่ให้ train:50 test:50 โมเดลมีค่า accuracy = 79%
# - เมื่อแบ่งข้อมูลแบบ cross-validation โมเดลมีค่า accuracy = 75%
#
# ดังนั้นการแบ่งข้อมูลแบบ simple hold out ที่ให้ train:50 test:50 จะได้โมเดล SVM ที่มีค่า accuracy มากที่สุด = 79%

# %% [markdown]
# # Decision Tree Method

# %% [markdown]
# ### เมื่อแบ่งข้อมูลแบบ simple hold out ที่ให้ train:80 test:20

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(feature_train, target_train)
predicted = model.predict(feature_test)
accuracy = accuracy_score(target_test, predicted)
print('accuracy = %.2f'%(accuracy))
# Out:
# accuracy = 0.70

# %% [markdown]
# #### Confustion Matrix

# %%
cm = confusion_matrix(target_test, predicted)
print(cm)
# Out:
# [[26  4]
#  [ 9  4]]

# %% [markdown]
# #### Precision

# %%
precision = metrics.precision_score(target_test, predicted)
print('precision = %.2f' %precision)
# Out:
# precision = 0.50

# %% [markdown]
# #### Recall

# %%
recall = metrics.recall_score(target_test, predicted)
print('recall = %.2f' %recall)
# Out:
# recall = 0.31

# %%
print(classification_report(target_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.87      0.80        30
#            1       0.50      0.31      0.38        13
#
#     accuracy                           0.70        43
#    macro avg       0.62      0.59      0.59        43
# weighted avg       0.67      0.70      0.67        43

# %% [markdown]
# ### เมื่อแบ่งข้อมูลแบบ simple hold out ที่ให้ train:50 test:50

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(feature_train2, target_train2)
predicted2 = model.predict(feature_test2)
accuracy = accuracy_score(target_test2, predicted2)
print('accuracy = %.2f'%(accuracy))
# Out:
# accuracy = 0.69

# %% [markdown]
# #### Confusion Matrix

# %%
cm = confusion_matrix(target_test2, predicted2)
print(cm)
# Out:
# [[66 17]
#  [16  8]]

# %% [markdown]
# #### Precision

# %%
precision = metrics.precision_score(target_test2, predicted2)
print('precision = %.2f' %precision)
# Out:
# precision = 0.32

# %% [markdown]
# #### Recall

# %%
recall = metrics.recall_score(target_test2, predicted2)
print('recall = %.2f' %recall)
# Out:
# recall = 0.33

# %%
print(classification_report(target_test2, predicted2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80        83
#            1       0.32      0.33      0.33        24
#
#     accuracy                           0.69       107
#    macro avg       0.56      0.56      0.56       107
# weighted avg       0.70      0.69      0.69       107

# %% [markdown]
# ### เมื่อแบ่งข้อมูลแบบ cross-validation

# %%
model = DecisionTreeClassifier()
acc_scores = cross_val_score(model, feature, target, cv=10, scoring="accuracy")
print("Dicision Tree : Mean cross-validation accuracy = %.2f" % acc_scores.mean() )
# Out:
# Dicision Tree : Mean cross-validation accuracy = 0.70

# %% [markdown]
# ### สรุป
# - เมื่อแบ่งข้อมูลแบบ simple hold out ที่ให้ train:80 test:20 โมเดลมีค่า accuracy = 70%
# - เมื่อแบ่งข้อมูลแบบ simple hold out ที่ให้ train:50 test:50 โมเดลมีค่า accuracy =69%
# - เมื่อแบ่งข้อมูลแบบ cross-validation โมเดลมีค่า accuracy = 70%
#
# ดังนั้นการแบ่งข้อมูลแบบ simple hold out ที่ให้ train:80 test:20 และ cross-validation จะได้โมเดล Decision Tree ที่มีค่า accuracy มากที่สุด = 70%

# %% [markdown]
# # Neural Network (NN) Method

# %% [markdown]
# ### เมื่อแบ่งข้อมูลแบบ simple hold out ที่ให้ train:80 test:20

# %%
model = Sequential()
model.add(Dense(15 ,activation='relu',input_shape=(feature_train.shape[1:])))
model.add(Dense(2, activation='softmax'))
opt = tf.keras.optimizers.Adam(lr=0.001, decay=0.00001)
model.compile(
    loss= "sparse_categorical_crossentropy",
    optimizer=opt,
    metrics='accuracy',
)
model.fit(feature_train, target_train, epochs=30, batch_size = 15)
predicted = model.predict(feature_test)
# Out:
# Epoch 1/30
# 12/12 [==============================] - 0s 999us/step - loss: 88.8572 - accuracy: 0.2398
# Epoch 2/30
# 12/12 [==============================] - 0s 1000us/step - loss: 69.1370 - accuracy: 0.2398
# Epoch 3/30
# 12/12 [==============================] - 0s 1ms/step - loss: 50.4797 - accuracy: 0.2398
# Epoch 4/30
# 12/12 [==============================] - 0s 1ms/step - loss: 31.8262 - accuracy: 0.2281
# Epoch 5/30
# 12/12 [==============================] - 0s 1ms/step - loss: 16.7128 - accuracy: 0.2924
# Epoch 6/30
# 12/12 [==============================] - 0s 999us/step - loss: 9.7915 - accuracy: 0.4269
# Epoch 7/30
# 12/12 [==============================] - 0s 1ms/step - loss: 8.4480 - accuracy: 0.5263
# Epoch 8/30
# 12/12 [==============================] - 0s 1ms/step - loss: 8.1678 - accuracy: 0.5906
# Epoch 9/30
# 12/12 [==============================] - 0s 1ms/step - loss: 7.7507 - accuracy: 0.5497
# Epoch 10/30
# 12/12 [==============================] - 0s 2ms/step - loss: 7.4471 - accuracy: 0.5205
# Epoch 11/30
# 12/12 [==============================] - 0s 1ms/step - loss: 7.1938 - accuracy: 0.5146
# Epoch 12/30
# 12/12 [==============================] - 0s 1ms/step - loss: 6.9446 - accuracy: 0.5263
# Epoch 13/30
# 12/12 [==============================] - 0s 1ms/step - loss: 6.6475 - accuracy: 0.5205
# Epoch 14/30
# 12/12 [==============================] - 0s 1ms/step - loss: 6.4345 - accuracy: 0.5380
# Epoch 15/30
# 12/12 [==============================] - 0s 1ms/step - loss: 6.1542 - accuracy: 0.5439
# Epoch 16/30
# 12/12 [==============================] - 0s 999us/step - loss: 5.8453 - accuracy: 0.5380
# Epoch 17/30
# 12/12 [==============================] - 0s 1ms/step - loss: 5.5759 - accuracy: 0.5322
# Epoch 18/30
# 12/12 [==============================] - 0s 999us/step - loss: 5.2271 - accuracy: 0.5322
# Epoch 19/30
# 12/12 [==============================] - 0s 999us/step - loss: 4.9931 - accuracy: 0.5439
# Epoch 20/30
# 12/12 [==============================] - 0s 1ms/step - loss: 4.6471 - accuracy: 0.5497
# Epoch 21/30
# 12/12 [==============================] - 0s 999us/step - loss: 4.3308 - accuracy: 0.5556
# Epoch 22/30
# 12/12 [==============================] - 0s 2ms/step - loss: 4.0634 - accuracy: 0.5673
# Epoch 23/30
# 12/12 [==============================] - 0s 1ms/step - loss: 3.7955 - accuracy: 0.5205
# Epoch 24/30
# 12/12 [==============================] - 0s 1ms/step - loss: 3.3590 - accuracy: 0.5789
# Epoch 25/30
# 12/12 [==============================] - 0s 999us/step - loss: 3.0766 - accuracy: 0.5614
# Epoch 26/30
# 12/12 [==============================] - 0s 1ms/step - loss: 2.6135 - accuracy: 0.5439
# Epoch 27/30
# 12/12 [==============================] - 0s 1ms/step - loss: 2.2667 - accuracy: 0.5673
# Epoch 28/30
# 12/12 [==============================] - 0s 1ms/step - loss: 1.9901 - accuracy: 0.5439
# Epoch 29/30
# 12/12 [==============================] - 0s 999us/step - loss: 1.7723 - accuracy: 0.6374
# Epoch 30/30
# 12/12 [==============================] - 0s 1ms/step - loss: 1.6137 - accuracy: 0.6257

# %%
test = tf.argmax(predicted, axis=1).numpy()
accuracy = accuracy_score(target_test, test)
print('accuracy = %.2f'%(accuracy))
# Out:
# accuracy = 0.58

# %% [markdown]
# #### Confusion Matrix

# %%
cm = confusion_matrix(target_test, test)
print(cm)
# Out:
# [[24  6]
#  [12  1]]

# %% [markdown]
# #### Precision

# %%
precision = metrics.precision_score(target_test, test)
print('precision = %.2f' %precision)
# Out:
# precision = 0.14

# %% [markdown]
# #### Recall

# %%
recall = metrics.recall_score(target_test, test)
print('recall = %.2f' %recall)
# Out:
# recall = 0.08

# %%
print(classification_report(target_test, test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73        30
#            1       0.14      0.08      0.10        13
#
#     accuracy                           0.58        43
#    macro avg       0.40      0.44      0.41        43
# weighted avg       0.51      0.58      0.54        43

# %% [markdown]
# ### เมื่อแบ่งข้อมูลแบบ simple hold out ที่ให้ train:50 test:50

# %%
model = Sequential()
model.add(Dense(15 ,activation='relu',input_shape=(feature_train2.shape[1:])))
model.add(Dense(2, activation='softmax'))
opt = tf.keras.optimizers.Adam(lr=0.001, decay=0.00001)
model.compile(
    loss= "sparse_categorical_crossentropy",
    optimizer=opt,
    metrics='accuracy',
)
model.fit(feature_train2, target_train2, epochs=30, batch_size = 15)
predicted2 = model.predict(feature_test2)
# Out:
# Epoch 1/30
# 8/8 [==============================] - 0s 1ms/step - loss: 3.6500 - accuracy: 0.5140
# Epoch 2/30
# 8/8 [==============================] - 0s 1ms/step - loss: 3.2745 - accuracy: 0.5421
# Epoch 3/30
# 8/8 [==============================] - 0s 1ms/step - loss: 3.0692 - accuracy: 0.5514
# Epoch 4/30
# 8/8 [==============================] - 0s 1ms/step - loss: 3.2170 - accuracy: 0.4299
# Epoch 5/30
# 8/8 [==============================] - 0s 1ms/step - loss: 2.6951 - accuracy: 0.4860
# Epoch 6/30
# 8/8 [==============================] - 0s 1ms/step - loss: 2.5968 - accuracy: 0.5794
# Epoch 7/30
# 8/8 [==============================] - 0s 1ms/step - loss: 2.4574 - accuracy: 0.4953
# Epoch 8/30
# 8/8 [==============================] - 0s 999us/step - loss: 2.2747 - accuracy: 0.5514
# Epoch 9/30
# 8/8 [==============================] - 0s 1ms/step - loss: 2.5201 - accuracy: 0.6168
# Epoch 10/30
# 8/8 [==============================] - 0s 1ms/step - loss: 2.5826 - accuracy: 0.4766
# Epoch 11/30
# 8/8 [==============================] - 0s 1ms/step - loss: 2.2084 - accuracy: 0.5888
# Epoch 12/30
# 8/8 [==============================] - 0s 1000us/step - loss: 1.9505 - accuracy: 0.6262
# Epoch 13/30
# 8/8 [==============================] - 0s 1ms/step - loss: 2.0742 - accuracy: 0.4766
# Epoch 14/30
# 8/8 [==============================] - 0s 1ms/step - loss: 1.7760 - accuracy: 0.6168
# Epoch 15/30
# 8/8 [==============================] - 0s 1ms/step - loss: 1.7079 - accuracy: 0.5794
# Epoch 16/30
# 8/8 [==============================] - 0s 1ms/step - loss: 1.7490 - accuracy: 0.4673
# Epoch 17/30
# 8/8 [==============================] - 0s 1ms/step - loss: 2.1990 - accuracy: 0.6822
# Epoch 18/30
# 8/8 [==============================] - 0s 999us/step - loss: 1.5408 - accuracy: 0.6262
# Epoch 19/30
# 8/8 [==============================] - 0s 2ms/step - loss: 1.7254 - accuracy: 0.4766
# Epoch 20/30
# 8/8 [==============================] - 0s 1ms/step - loss: 1.3766 - accuracy: 0.6542
# Epoch 21/30
# 8/8 [==============================] - 0s 1ms/step - loss: 1.3208 - accuracy: 0.6262
# Epoch 22/30
# 8/8 [==============================] - 0s 999us/step - loss: 1.2453 - accuracy: 0.6449
# Epoch 23/30
# 8/8 [==============================] - 0s 1ms/step - loss: 1.2342 - accuracy: 0.6355
# Epoch 24/30
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1944 - accuracy: 0.6822
# Epoch 25/30
# 8/8 [==============================] - 0s 1ms/step - loss: 1.1404 - accuracy: 0.5794
# Epoch 26/30
# 8/8 [==============================] - 0s 1ms/step - loss: 0.9941 - accuracy: 0.6355
# Epoch 27/30
# 8/8 [==============================] - 0s 1ms/step - loss: 1.2988 - accuracy: 0.6822
# Epoch 28/30
# 8/8 [==============================] - 0s 1ms/step - loss: 0.9302 - accuracy: 0.6822
# Epoch 29/30
# 8/8 [==============================] - 0s 1ms/step - loss: 0.8972 - accuracy: 0.7383
# Epoch 30/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9689 - accuracy: 0.6449

# %%
test = tf.argmax(predicted2, axis=1).numpy()
accuracy = accuracy_score(target_test2, test)
print('accuracy = %.2f'%(accuracy))
# Out:
# accuracy = 0.57

# %% [markdown]
# #### Precision

# %%
precision = metrics.precision_score(target_test2, test)
print('precision = %.2f' %precision)
# Out:
# precision = 0.19

# %% [markdown]
# #### Recall

# %%
recall = metrics.recall_score(target_test2, test)
print('recall = %.2f' %recall)
# Out:
# recall = 0.29

# %%
print(classification_report(target_test2, test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.65      0.70        83
#            1       0.19      0.29      0.23        24
#
#     accuracy                           0.57       107
#    macro avg       0.48      0.47      0.47       107
# weighted avg       0.63      0.57      0.60       107

# %% [markdown]
# ### สรุป
# - เมื่อแบ่งข้อมูลแบบ simple hold out ที่ให้ train:80 test:20 โมเดลมีค่า accuracy = 58%
# - เมื่อแบ่งข้อมูลแบบ simple hold out ที่ให้ train:50 test:50 โมเดลมีค่า accuracy = 57%
#
# ดังนั้นการแบ่งข้อมูลแบบ simple hold out ที่ให้ train:80 test:20 จะได้โมเดล Neural Network (NN) ที่มีค่า accuracy มากที่สุด = 58%

# %% [markdown]
# การแบ่งข้อมูลแบบ simple hold out ที่ให้ train:50 test:50 จะได้โมเดล Logistic Regression ที่มีค่า accuracy มากที่สุด = 80%
# การแบ่งข้อมูลแบบ simple hold out ที่ให้ train:50 test:50 จะได้โมเดล KNN ที่มีค่า accuracy มากที่สุด = 76%
# การแบ่งข้อมูลแบบ simple hold out ที่ให้ train:50 test:50 จะได้โมเดล SVM ที่มีค่า accuracy มากที่สุด = 79%
# การแบ่งข้อมูลแบบ simple hold out ที่ให้ train:80 test:20 และ cross-validation จะได้โมเดล Decision Tree ที่มีค่า accuracy มากที่สุด = 70%
# การแบ่งข้อมูลแบบ simple hold out ที่ให้ train:80 test:20 จะได้โมเดล Neural Network (NN) ที่มีค่า accuracy มากที่สุด = 58%

# %% [markdown]
# ดังนั้นเมื่อแบ่งข้อมูลแบบ simple hold out ที่ให้ train:50 test:50 โมเดล Logistic Regression จะมีค่า accuracy = 80% ซึ่งมากที่สุด

# %% [markdown]
# # Reference

# %% [markdown]
# Detrano, R., Janosi, A., Steinbrunn, W., Pfisterer, M., Schmid, J., Sandhu, S., Guppy, K., Lee, S., & Froelicher, V. (1989). International application of a new probability algorithm for the diagnosis of coronary artery disease. American Journal of Cardiology, 64,304--310.
# [Web Link]
#
# David W. Aha & Dennis Kibler. "Instance-based prediction of heart-disease presence with the Cleveland database."
# [Web Link]
#
# Gennari, J.H., Langley, P, & Fisher, D. (1989). Models of incremental concept formation. Artificial Intelligence, 40, 11--61.
# [Web Link]

# %% [markdown]
# # END
